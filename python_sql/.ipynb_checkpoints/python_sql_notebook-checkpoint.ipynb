# %%
import os 
try:
    os.remove('airline2.db')
except OSError:
    pass

# %%
import sqlite3
conn = sqlite3.connect('airline2.db')

# %%
import pandas as pd

ontime = pd.read_csv("/home/max/LSE/DB_local_only/dataverse_files/2000.csv")
#airports = pd.read_csv("/home/max/LSE/DB_local_only/dataverse_files/airports.csv")
#carriers = pd.read_csv("/home/max/LSE/DB_local_only/dataverse_files/carriers.csv")
#planes = pd.read_csv("/home/max/LSE/DB_local_only/dataverse_files/plane_data.csv")

# %%
pd.DataFrame(ontime)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2000      1          28          5   1647.0        1647   1906.0
# 1        2000      1          29          6   1648.0        1647   1939.0
# 2        2000      1          30          7      NaN        1647      NaN
# 3        2000      1          31          1   1645.0        1647   1852.0
# 4        2000      1           1          6    842.0         846   1057.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 5683042  2000     12           9          6    615.0         613    941.0
# 5683043  2000     12          10          7    619.0         613    925.0
# 5683044  2000     12          11          1    611.0         613    949.0
# 5683045  2000     12          12          2    613.0         613   1005.0
# 5683046  2000     12          13          3    614.0         613    948.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %% [markdown]
# import sqlite3
# conn = sqlite3.connect('airline2.db')
